# %%
import osmnx as ox
# Out:
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/osmnx/projection.py:3: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
from typing import Optional, Iterable, Tuple
import requests
import pandas as pd
from pathlib import Path
from tqdm import tqdm

def download_tile_with_progress(tile_id: str, output_file: Path, access_token: str):
    url = f"https://catalogue.dataspace.copernicus.eu/odata/v1/Products({tile_id})/$value"
    
    s = requests.Session()
    s.headers.update({"Authorization": f"Bearer {access_token}"})
    
    response = s.head(url, allow_redirects=False)
    while response.status_code in (301, 302, 303, 307):
        url = response.headers['Location']
        response = s.head(url, allow_redirects=False)
    
    chunk_size = 2**20  # mb
    with s.get(url, stream=True) as resp:
        with open(output_file, "wb") as f:
            print(f"Saving to {output_file}")
            for data in tqdm(
                resp.iter_content(chunk_size=chunk_size), 
                total=int(resp.headers.get("content-length", 0)) // chunk_size, 
                unit="MB",
                unit_scale=True,
                desc="Downloading...",
            ):
                f.write(data)

# if not os.path.exists(tile_path_zip):
#     print(f"Downloading tile with ID {tile_id}")
#     download_tile_with_progress(tile_id, tile_path_zip, access_token)

# %%
cities = ["Berlin", "Milan", "sanktpetersburg", "Odessa", "New York", "London", "Krasnodar", "Paris", "Barcelona", "Amsterdam"]

# %%
buildings = ox.features_from_place("Bologna", tags={'building':True})
buildings.plot()
# Out:
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/shapely/set_operations.py:340: RuntimeWarning: invalid value encountered in union
#   return lib.union(a, b, **kwargs)
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/pygeos/predicates.py:764: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/pygeos/predicates.py:764: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/pygeos/predicates.py:764: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/pygeos/predicates.py:764: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/pygeos/predicates.py:764: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/pygeos/predicates.py:764: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/pygeos/predicates.py:764: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# <Axes: >

# %%
import openeo

connection = openeo.connect("openeo.dataspace.copernicus.eu")
connection.authenticate_oidc()
# Out:
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/openeo/rest/connection.py:313: ResourceWarning: unclosed <ssl.SSLSocket fd=90, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('192.168.1.51', 57198), raddr=('185.48.232.146', 443)>
#   root_url=self.version_discovery(url, session=session, timeout=default_timeout),
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/openeo/rest/auth/oidc.py:282: ResourceWarning: unclosed <ssl.SSLSocket fd=91, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('192.168.1.51', 57200), raddr=('91.212.141.68', 443)>
#   return cls(
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# Authenticated using refresh token.
# /var/folders/yn/hmxc2n8n47b0_cp42wr40nb40000gn/T/ipykernel_9946/2394854157.py:4: ResourceWarning: unclosed <ssl.SSLSocket fd=91, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('192.168.1.51', 57201), raddr=('91.212.141.68', 443)>
#   connection.authenticate_oidc()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# <Connection to 'https://openeo.dataspace.copernicus.eu/openeo/1.2/' with OidcBearerAuth>

# %%
from pathlib import Path

DATASET_DIR = Path("datasets")
DATASET_DIR.mkdir(parents=True, exist_ok=True)

BUILDING_DATASET_DIR = DATASET_DIR / "building_footprints"
BUILDING_DATASET_DIR.mkdir(parents=True, exist_ok=True)

SENTINEL_DATASET_DIR = DATASET_DIR / "sentinel"
SENTINEL_DATASET_DIR.mkdir(parents=True, exist_ok=True)

# %%
bologna_gdf = ox.geocode_to_gdf("Bologna, Italy")
bologna_gdf.envelope.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1762939db301796c461709f3c38d2956 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1762939db301796c461709f3c38d2956&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1762939db301796c461709f3c38d2956 = L.map(
#                 &quot;map_1762939db301796c461709f3c38d2956&quot;,
#                 {
#                     center: [44.4885736, 11.331614250000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1762939db301796c461709f3c38d2956);
#
#
#
#
#
#             var tile_layer_882a24a50d72d582051483ea34536194 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1762939db301796c461709f3c38d2956);
#
#
#             map_1762939db301796c461709f3c38d2956.fitBounds(
#                 [[44.4210532, 11.2296206], [44.556094, 11.4336079]],
#                 {}
#             );
#
#
#         function geo_json_92f30c9572858ab1042a4df8e12635f4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_92f30c9572858ab1042a4df8e12635f4_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_92f30c9572858ab1042a4df8e12635f4_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_92f30c9572858ab1042a4df8e12635f4_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_92f30c9572858ab1042a4df8e12635f4_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_92f30c9572858ab1042a4df8e12635f4.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_92f30c9572858ab1042a4df8e12635f4_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_92f30c9572858ab1042a4df8e12635f4 = L.geoJson(null, {
#                 onEachFeature: geo_json_92f30c9572858ab1042a4df8e12635f4_onEachFeature,
#
#                 style: geo_json_92f30c9572858ab1042a4df8e12635f4_styler,
#                 pointToLayer: geo_json_92f30c9572858ab1042a4df8e12635f4_pointToLayer
#         });
#
#         function geo_json_92f30c9572858ab1042a4df8e12635f4_add (data) {
#             geo_json_92f30c9572858ab1042a4df8e12635f4
#                 .addData(data)
#                 .addTo(map_1762939db301796c461709f3c38d2956);
#         }
#             geo_json_92f30c9572858ab1042a4df8e12635f4_add({&quot;bbox&quot;: [11.2296206, 44.4210532, 11.4336079, 44.556094], &quot;features&quot;: [{&quot;bbox&quot;: [11.2296206, 44.4210532, 11.4336079, 44.556094], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[11.2296206, 44.4210532], [11.4336079, 44.4210532], [11.4336079, 44.556094], [11.2296206, 44.556094], [11.2296206, 44.4210532]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
bologna_gdf
# Out:
#                                             geometry  bbox_north  bbox_south
# 0  POLYGON ((11.22962 44.53049, 11.22969 44.53012...   44.556094   44.421053  \
#
#    bbox_east  bbox_west  place_id  osm_type  osm_id       lat        lon
# 0  11.433608  11.229621  65308066  relation   43172  44.49382  11.342633  \
#
#       class            type  place_rank  importance addresstype     name
# 0  boundary  administrative          16    0.680577        city  Bologna  \
#
#                      display_name
# 0  Bologna, Emilia-Romagna, Italy

# %%
#from openeo.processes import collection, filter_bbox, filter_daterange, download

def download_sentinel_openeo(connection, bbox, path):

    s2_cube = connection.load_collection(
        "SENTINEL2_L2A",
        temporal_extent=("2022-05-01", "2022-05-30"),
        spatial_extent={
            "west": bbox["west"],
            "south": bbox["south"],
            "east": bbox["east"],
            "north": bbox["north"]
        },
        bands=["B04", "B03", "B02", "B08"],
        max_cloud_cover=50,
    )
    
    R_band = s2_cube.band("B04")
    R_band.download(path / "R.tiff")
    G_band = s2_cube.band("B03")
    G_band.download(path / "G.tiff")
    B_band = s2_cube.band("B02")
    B_band.download(path / "B.tiff")
    IR_band = s2_cube.band("B08")
    IR_band.download(path / "IR.tiff")

# %%
bbox = {
    "north": bologna_gdf.bbox_north[0],
    "south": bologna_gdf.bbox_south[0],
    "east": bologna_gdf.bbox_east[0],
    "west": bologna_gdf.bbox_west[0]
}
bolognia_features = ox.features_from_bbox(north=bbox["north"], south=bbox["south"], east=bbox["east"], west=bbox["west"], tags={'building':True})
# Out:
# /var/folders/yn/hmxc2n8n47b0_cp42wr40nb40000gn/T/ipykernel_9946/3545391186.py:7: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead.
#   bolognia_features = ox.features_from_bbox(north=bbox["north"], south=bbox["south"], east=bbox["east"], west=bbox["west"], tags={'building':True})
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/shapely/set_operations.py:340: RuntimeWarning: invalid value encountered in union
#   return lib.union(a, b, **kwargs)
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/pygeos/predicates.py:764: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/pygeos/predicates.py:764: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)

# %%
download_sentinel_openeo(connection, bbox=bbox, path=SENTINEL_DATASET_DIR)
# Out:
# Failed to parse API error response: [503] 'no available server\n' (headers: {'Cache-Status': 'miss', 'Content-Type': 'text/plain; charset=utf-8', 'X-Content-Type-Options': 'nosniff', 'Date': 'Fri, 28 Jun 2024 11:31:19 GMT', 'Content-Length': '20'})
# ---------------------------------------------------------------------------
# OpenEoApiPlainError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 download_sentinel_openeo(connection, bbox=bbox, path=SENTINEL_DATASET_DIR)
#
# Cell In[8], line 5, in download_sentinel_openeo(connection, bbox, path)
#       3 def download_sentinel_openeo(connection, bbox, path):
# ----> 5     s2_cube = connection.load_collection(
#       6         "SENTINEL2_L2A",
#       7         temporal_extent=("2022-05-01", "2022-05-30"),
#       8         spatial_extent={
#       9             "west": bbox["west"],
#      10             "south": bbox["south"],
#      11             "east": bbox["east"],
#      12             "north": bbox["north"]
#      13         },
#      14         bands=["B04", "B03", "B02", "B08"],
#      15         max_cloud_cover=50,
#      16     )
#      18     R_band = s2_cube.band("B04")
#      19     R_band.download(path / "R.tiff")
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/openeo/rest/connection.py:1215, in Connection.load_collection(self, collection_id, spatial_extent, temporal_extent, bands, properties, max_cloud_cover, fetch_metadata)
#    1178 @openeo_process
#    1179 def load_collection(
#    1180     self,
#    (...)
#    1189     fetch_metadata: bool = True,
#    1190 ) -> DataCube:
#    1191     """
#    1192     Load a DataCube by collection id.
#    1193
#    (...)
#    1213         Add :py:func:`~openeo.rest.graph_building.collection_property` support to ``properties`` argument.
#    1214     """
# -> 1215     return DataCube.load_collection(
#    1216         collection_id=collection_id,
#    1217         connection=self,
#    1218         spatial_extent=spatial_extent,
#    1219         temporal_extent=temporal_extent,
#    1220         bands=bands,
#    1221         properties=properties,
#    1222         max_cloud_cover=max_cloud_cover,
#    1223         fetch_metadata=fetch_metadata,
#    1224     )
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/openeo/rest/datacube.py:192, in DataCube.load_collection(cls, collection_id, connection, spatial_extent, temporal_extent, bands, fetch_metadata, properties, max_cloud_cover)
#     189 if isinstance(collection_id, Parameter):
#     190     fetch_metadata = False
#     191 metadata: Optional[CollectionMetadata] = (
# --> 192     connection.collection_metadata(collection_id) if fetch_metadata else None
#     193 )
#     194 if bands:
#     195     if isinstance(bands, str):
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/openeo/rest/connection.py:970, in Connection.collection_metadata(self, name)
#     968 def collection_metadata(self, name) -> CollectionMetadata:
#     969     # TODO: duplication with `Connection.describe_collection`: deprecate one or the other?
# --> 970     return CollectionMetadata(metadata=self.describe_collection(name))
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/openeo/rest/connection.py:927, in Connection.describe_collection(self, collection_id)
#     914 """
#     915 Get full collection metadata for given collection id.
#     916
#    (...)
#     923 :return: collection metadata.
#     924 """
#     925 # TODO: duplication with `Connection.collection_metadata`: deprecate one or the other?
#     926 # TODO: add caching #383
# --> 927 data = self.get(f"/collections/{collection_id}", expected_status=200).json()
#     928 return VisualDict("collection", data=data)
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/openeo/rest/connection.py:239, in RestApiConnection.get(self, path, stream, auth, **kwargs)
#     230 def get(self, path: str, stream: bool = False, auth: Optional[AuthBase] = None, **kwargs) -> Response:
#     231     """
#     232     Do GET request to REST API.
#     233
#    (...)
#     237     :return: response: Response
#     238     """
# --> 239     return self.request("get", path=path, stream=stream, auth=auth, **kwargs)
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/openeo/rest/connection.py:788, in Connection.request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     781     return super(Connection, self).request(
#     782         method=method, path=path, headers=headers, auth=auth,
#     783         check_error=check_error, expected_status=expected_status, **kwargs,
#     784     )
#     786 try:
#     787     # Initial request attempt
# --> 788     return _request()
#     789 except OpenEoApiError as api_exc:
#     790     if api_exc.http_status_code in {401, 403} and api_exc.code == "TokenInvalid":
#     791         # Auth token expired: can we refresh?
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/openeo/rest/connection.py:781, in Connection.request.<locals>._request()
#     780 def _request():
# --> 781     return super(Connection, self).request(
#     782         method=method, path=path, headers=headers, auth=auth,
#     783         check_error=check_error, expected_status=expected_status, **kwargs,
#     784     )
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/openeo/rest/connection.py:187, in RestApiConnection.request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     185 expected_status = ensure_list(expected_status) if expected_status else []
#     186 if check_error and status >= 400 and status not in expected_status:
# --> 187     self._raise_api_error(resp)
#     188 if expected_status and status not in expected_status:
#     189     raise OpenEoRestError("Got status code {s!r} for `{m} {p}` (expected {e!r}) with body {body}".format(
#     190         m=method.upper(), p=path, s=status, e=expected_status, body=resp.text)
#     191     )
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/openeo/rest/connection.py:228, in RestApiConnection._raise_api_error(self, response)
#     221 if status_code == 502 and "Proxy Error" in text:
#     222     error_message = (
#     223         "Received 502 Proxy Error."
#     224         " This typically happens when a synchronous openEO processing request takes too long and is aborted."
#     225         " Consider using a batch job instead."
#     226     )
# --> 228 raise OpenEoApiPlainError(message=text, http_status_code=status_code, error_message=error_message)
#
# OpenEoApiPlainError: [503] no available server

# %%
import rasterio
from matplotlib import pyplot as plt
import numpy as np

img = rasterio.open(SENTINEL_DATASET_DIR / "R.tiff")
img_array = img.read().squeeze()

def vis(img):
    masked_data = np.ma.masked_equal(img, 0)
    lq, uq = np.quantile(masked_data.compressed(), (0.01, 0.99))
    data = np.clip(img, a_min=lq, a_max=uq)
    data = (data - lq) / (uq - lq)
    if data.ndim == 2:
        plt.imshow(data, cmap="gray")
    elif data.ndim == 3:
        plt.imshow(data)
    return data

# %%
with rasterio.open(SENTINEL_DATASET_DIR / "all_bands.tiff") as f:
    data = f.read()
all_band_data = np.transpose(data, (1,2,0))
rgb_data = all_band_data[:,:,:3]
irgb_data = np.stack(
    [
        all_band_data[..., 0],
        all_band_data[..., 1],
        all_band_data[..., 2]
    ],
    axis=-1
)
vis(irgb_data)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio/_base.pyx:308, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:219, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:221, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: datasets/sentinel/all_bands.tiff: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 with rasterio.open(SENTINEL_DATASET_DIR / "all_bands.tiff") as f:
#       2     data = f.read()
#       3 all_band_data = np.transpose(data, (1,2,0))
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/rasterio/env.py:451, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     448     session = DummySession()
#     450 with env_ctor(session=session):
# --> 451     return f(*args, **kwds)
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/rasterio/__init__.py:304, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     301 path = _parse_path(raw_dataset_path)
#     303 if mode == "r":
# --> 304     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     305 elif mode == "r+":
#     306     dataset = get_writer_for_path(path, driver=driver)(
#     307         path, mode, driver=driver, sharing=sharing, **kwargs
#     308     )
#
# File rasterio/_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: datasets/sentinel/all_bands.tiff: No such file or directory

# %%
with rasterio.open(SENTINEL_DATASET_DIR / "R.tiff") as f:
    r_data = np.transpose(f.read(), (1,2,0)).squeeze()
with rasterio.open(SENTINEL_DATASET_DIR / "G.tiff") as f:
    g_data = np.transpose(f.read(), (1,2,0)).squeeze()    
with rasterio.open(SENTINEL_DATASET_DIR / "B.tiff") as f:
    b_data = np.transpose(f.read(), (1,2,0)).squeeze()
with rasterio.open(SENTINEL_DATASET_DIR / "IR.tiff") as f:
    ir_data = np.transpose(f.read(), (1,2,0)).squeeze()

rgb_data = np.stack(
    [
       r_data,
       g_data,
       b_data 
    ],
    axis=-1
)
rgb_img = vis(rgb_data)

# %%
irb_data = np.stack(
    [
       ir_data,
       r_data,
       b_data 
    ],
    axis=-1
)
irb_img = vis(irb_data)

# %%
r_img = vis(r_data)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(r_img, cmap="gray", extent=(buildings.total_bounds[0], buildings.total_bounds[2], buildings.total_bounds[1], buildings.total_bounds[3]))
buildings.plot(ax=ax, facecolor='none', edgecolor='blue', linewidth=0.5, alpha=0.2)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
buildings.plot(ax=ax, facecolor='none', edgecolor='blue', linewidth=0.5, alpha=0.2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 2
#       1 fig, ax = plt.subplots(figsize=(10, 10))
# ----> 2 buildings.plot(ax=ax, facecolor='none', edgecolor='blue', linewidth=0.5, alpha=0.2)
#       3 plt.show()
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/geopandas/plotting.py:968, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     966 kind = kwargs.pop("kind", "geo")
#     967 if kind == "geo":
# --> 968     return plot_dataframe(data, *args, **kwargs)
#     969 if kind in self._pandas_kinds:
#     970     # Access pandas plots
#     971     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/geopandas/plotting.py:704, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     701     markersize = df[markersize].values
#     703 if column is None:
# --> 704     return plot_series(
#     705         df.geometry,
#     706         cmap=cmap,
#     707         color=color,
#     708         ax=ax,
#     709         figsize=figsize,
#     710         markersize=markersize,
#     711         aspect=aspect,
#     712         **style_kwds,
#     713     )
#     715 # To accept pd.Series and np.arrays as column
#     716 if isinstance(column, (np.ndarray, pd.Series)):
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/geopandas/plotting.py:458, in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     455         facecolor = color_
#     457     values_ = values[poly_idx] if cmap else None
# --> 458     _plot_polygon_collection(
#     459         ax, polys, values_, facecolor=facecolor, cmap=cmap, **style_kwds
#     460     )
#     462 # plot all LineStrings and MultiLineString components in same collection
#     463 lines = expl_series[line_idx]
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/geopandas/plotting.py:175, in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#     170     kwargs["color"] = color
#     172 _expand_kwargs(kwargs, multiindex)
#     174 collection = PatchCollection(
# --> 175     [_PolygonPatch(poly) for poly in geoms if not poly.is_empty], **kwargs
#     176 )
#     178 if values is not None:
#     179     collection.set_array(np.asarray(values))
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/geopandas/plotting.py:175, in <listcomp>(.0)
#     170     kwargs["color"] = color
#     172 _expand_kwargs(kwargs, multiindex)
#     174 collection = PatchCollection(
# --> 175     [_PolygonPatch(poly) for poly in geoms if not poly.is_empty], **kwargs
#     176 )
#     178 if values is not None:
#     179     collection.set_array(np.asarray(values))
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/geopandas/plotting.py:119, in _PolygonPatch(polygon, **kwargs)
#     116 from matplotlib.patches import PathPatch
#     117 from matplotlib.path import Path
# --> 119 path = Path.make_compound_path(
#     120     Path(np.asarray(polygon.exterior.coords)[:, :2]),
#     121     *[Path(np.asarray(ring.coords)[:, :2]) for ring in polygon.interiors],
#     122 )
#     123 return PathPatch(path, **kwargs)
#
# File /opt/anaconda3/envs/sentsegm/lib/python3.9/site-packages/matplotlib/path.py:341, in Path.make_compound_path(cls, *args)
#     339     i += len(path.vertices)
#     340 # remove STOP's, since internal STOPs are a bug
# --> 341 not_stop_mask = codes != cls.STOP
#     342 vertices = vertices[not_stop_mask, :]
#     343 codes = codes[not_stop_mask]
#
# KeyboardInterrupt:
